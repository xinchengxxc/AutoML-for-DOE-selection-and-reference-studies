# %% [markdown]
# <img src="assets/logo.jpg" alt="HPC Builder Logo" width="64"/>
#
# # HPC Toolkit
#
# ARC - Aschaffenburger Research Cluster<br>
# Version 2024.5.1<br>
# _by Kat 2024_

# %% [markdown]
# #### Setup HPC Toolkit
#
# First, you'll need to setup some mandatory information before start using the **HPC Toolkit**. Create a file **__hpc_setup.yaml** in your workspace root folder and fill in all information:
#
# **Also:** Just put your yaml file in gitignore to avoid pushing that info to the repository.

# %%
from io import StringIO
import pandas as pd
import subprocess
import yaml
import hpctk

# load user HPC settings yaml
with open('../__hpc_creds.yaml', 'r') as file:
    config = yaml.safe_load(file)

# Access the variables
lab = config["lab"]
user = config["user"]
workspace_dir = config["workspace_dir"]
container_name = config["container_name"]
container_tag = config["container_tag"]
docker_file = config["docker_file"]
registry_host = config["registry_host"]
hpc_mn = config["hpc_mn"]
hpc_mn_project_base = config["hpc_mn_project_base"]
ssh_creds = config["ssh_creds"]

hpctk.print_hpc_setup_yaml(lab, user, container_name, container_tag, docker_file, registry_host, hpc_mn, ssh_creds, workspace_dir, hpc_mn_project_base)
# Out:
# <style type="text/css">
# #T_d65dd th {
#   background-color: #404040;
#   color: white;
#   border-color: black;
#   border-style: solid;
#   border-width: 1px;
# }
# #T_d65dd_row0_col0, #T_d65dd_row0_col1, #T_d65dd_row1_col0, #T_d65dd_row1_col1, #T_d65dd_row2_col0, #T_d65dd_row2_col1, #T_d65dd_row3_col0, #T_d65dd_row3_col1, #T_d65dd_row4_col0, #T_d65dd_row4_col1, #T_d65dd_row5_col0, #T_d65dd_row5_col1, #T_d65dd_row6_col0, #T_d65dd_row6_col1, #T_d65dd_row7_col0, #T_d65dd_row7_col1, #T_d65dd_row8_col0, #T_d65dd_row8_col1, #T_d65dd_row9_col0, #T_d65dd_row9_col1 {
#   background-color: #f4f4f4;
#   color: black;
#   border-color: black;
#   border-style: solid;
#   border-width: 1px;
#   text-align: left;
# }
# </style>
# <table id="T_d65dd">
#   <thead>
#     <tr>
#       <th id="T_d65dd_level0_col0" class="col_heading level0 col0" >Fact</th>
#       <th id="T_d65dd_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d65dd_row0_col0" class="data row0 col0" >lab</td>
#       <td id="T_d65dd_row0_col1" class="data row0 col1" >aghm</td>
#     </tr>
#     <tr>
#       <td id="T_d65dd_row1_col0" class="data row1 col0" >user</td>
#       <td id="T_d65dd_row1_col1" class="data row1 col1" >u230292</td>
#     </tr>
#     <tr>
#       <td id="T_d65dd_row2_col0" class="data row2 col0" >container_name</td>
#       <td id="T_d65dd_row2_col1" class="data row2 col1" >datagen</td>
#     </tr>
#     <tr>
#       <td id="T_d65dd_row3_col0" class="data row3 col0" >container_tag</td>
#       <td id="T_d65dd_row3_col1" class="data row3 col1" >latest</td>
#     </tr>
#     <tr>
#       <td id="T_d65dd_row4_col0" class="data row4 col0" >docker_file</td>
#       <td id="T_d65dd_row4_col1" class="data row4 col1" >Dockerfile</td>
#     </tr>
#     <tr>
#       <td id="T_d65dd_row5_col0" class="data row5 col0" >registry_host</td>
#       <td id="T_d65dd_row5_col1" class="data row5 col1" >DT-IW-20-028:5000</td>
#     </tr>
#     <tr>
#       <td id="T_d65dd_row6_col0" class="data row6 col0" >hpc_mn</td>
#       <td id="T_d65dd_row6_col1" class="data row6 col1" >10.32.118.9</td>
#     </tr>
#     <tr>
#       <td id="T_d65dd_row7_col0" class="data row7 col0" >ssh_creds</td>
#       <td id="T_d65dd_row7_col1" class="data row7 col1" >{'port': '44100', 'ssh_key_name': 'hpc_u230292', 'ssh_path': '~/.ssh', 'user': 'u230292'}</td>
#     </tr>
#     <tr>
#       <td id="T_d65dd_row8_col0" class="data row8 col0" >workspace_dir</td>
#       <td id="T_d65dd_row8_col1" class="data row8 col1" >data_gen</td>
#     </tr>
#     <tr>
#       <td id="T_d65dd_row9_col0" class="data row9 col0" >hpc_mn_project_base</td>
#       <td id="T_d65dd_row9_col1" class="data row9 col1" >/home_cu/u230292/Projects</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Get cluster detail status

# %%
# sinfo -lNe
try:
    rc = hpctk.run_remote(["sinfo -lNe"], hpc_mn, ssh_creds, stdout=False)
    hpctk.show_tab_styled(rc.stdout, 1, hpctk.highlight_state)

except subprocess.CalledProcessError as e:
    print(f"\n{hpctk.STATE_FAIL} Failed: {e.returncode}\n")
    print(f":: Error message: {e.stderr}")
# Out:
# <style type="text/css">
# #T_3936b_row0_col3, #T_3936b_row1_col3, #T_3936b_row2_col3, #T_3936b_row4_col3, #T_3936b_row5_col3, #T_3936b_row6_col3, #T_3936b_row7_col3, #T_3936b_row8_col3, #T_3936b_row9_col3, #T_3936b_row10_col3 {
#   color: white;
#   background-color: red;
# }
# #T_3936b_row3_col3 {
#   color: white;
#   background-color: green;
# }
# </style>
# <table id="T_3936b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3936b_level0_col0" class="col_heading level0 col0" >NODELIST</th>
#       <th id="T_3936b_level0_col1" class="col_heading level0 col1" >NODES</th>
#       <th id="T_3936b_level0_col2" class="col_heading level0 col2" >PARTITION</th>
#       <th id="T_3936b_level0_col3" class="col_heading level0 col3" >STATE</th>
#       <th id="T_3936b_level0_col4" class="col_heading level0 col4" >CPUS</th>
#       <th id="T_3936b_level0_col5" class="col_heading level0 col5" >S:C:T</th>
#       <th id="T_3936b_level0_col6" class="col_heading level0 col6" >MEMORY</th>
#       <th id="T_3936b_level0_col7" class="col_heading level0 col7" >TMP_DISK</th>
#       <th id="T_3936b_level0_col8" class="col_heading level0 col8" >WEIGHT</th>
#       <th id="T_3936b_level0_col9" class="col_heading level0 col9" >AVAIL_FE</th>
#       <th id="T_3936b_level0_col10" class="col_heading level0 col10" >REASON</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3936b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3936b_row0_col0" class="data row0 col0" >DT-IW-20-006</td>
#       <td id="T_3936b_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_3936b_row0_col2" class="data row0 col2" >universe*</td>
#       <td id="T_3936b_row0_col3" class="data row0 col3" >mixed</td>
#       <td id="T_3936b_row0_col4" class="data row0 col4" >8</td>
#       <td id="T_3936b_row0_col5" class="data row0 col5" >1:4:2</td>
#       <td id="T_3936b_row0_col6" class="data row0 col6" >59816</td>
#       <td id="T_3936b_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_3936b_row0_col8" class="data row0 col8" >1</td>
#       <td id="T_3936b_row0_col9" class="data row0 col9" >(null)</td>
#       <td id="T_3936b_row0_col10" class="data row0 col10" >none</td>
#     </tr>
#     <tr>
#       <th id="T_3936b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3936b_row1_col0" class="data row1 col0" >DT-IW-20-041</td>
#       <td id="T_3936b_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_3936b_row1_col2" class="data row1 col2" >universe*</td>
#       <td id="T_3936b_row1_col3" class="data row1 col3" >allocated</td>
#       <td id="T_3936b_row1_col4" class="data row1 col4" >6</td>
#       <td id="T_3936b_row1_col5" class="data row1 col5" >1:6:1</td>
#       <td id="T_3936b_row1_col6" class="data row1 col6" >124527</td>
#       <td id="T_3936b_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_3936b_row1_col8" class="data row1 col8" >1</td>
#       <td id="T_3936b_row1_col9" class="data row1 col9" >(null)</td>
#       <td id="T_3936b_row1_col10" class="data row1 col10" >none</td>
#     </tr>
#     <tr>
#       <th id="T_3936b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3936b_row2_col0" class="data row2 col0" >DT-IW-20-044</td>
#       <td id="T_3936b_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_3936b_row2_col2" class="data row2 col2" >universe*</td>
#       <td id="T_3936b_row2_col3" class="data row2 col3" >allocated</td>
#       <td id="T_3936b_row2_col4" class="data row2 col4" >6</td>
#       <td id="T_3936b_row2_col5" class="data row2 col5" >1:6:1</td>
#       <td id="T_3936b_row2_col6" class="data row2 col6" >59938</td>
#       <td id="T_3936b_row2_col7" class="data row2 col7" >0</td>
#       <td id="T_3936b_row2_col8" class="data row2 col8" >1</td>
#       <td id="T_3936b_row2_col9" class="data row2 col9" >(null)</td>
#       <td id="T_3936b_row2_col10" class="data row2 col10" >none</td>
#     </tr>
#     <tr>
#       <th id="T_3936b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3936b_row3_col0" class="data row3 col0" >DT-IW-20-051</td>
#       <td id="T_3936b_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_3936b_row3_col2" class="data row3 col2" >testing</td>
#       <td id="T_3936b_row3_col3" class="data row3 col3" >idle</td>
#       <td id="T_3936b_row3_col4" class="data row3 col4" >6</td>
#       <td id="T_3936b_row3_col5" class="data row3 col5" >1:6:1</td>
#       <td id="T_3936b_row3_col6" class="data row3 col6" >124527</td>
#       <td id="T_3936b_row3_col7" class="data row3 col7" >0</td>
#       <td id="T_3936b_row3_col8" class="data row3 col8" >1</td>
#       <td id="T_3936b_row3_col9" class="data row3 col9" >(null)</td>
#       <td id="T_3936b_row3_col10" class="data row3 col10" >none</td>
#     </tr>
#     <tr>
#       <th id="T_3936b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3936b_row4_col0" class="data row4 col0" >DT-IW-24-062</td>
#       <td id="T_3936b_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_3936b_row4_col2" class="data row4 col2" >universe*</td>
#       <td id="T_3936b_row4_col3" class="data row4 col3" >mixed</td>
#       <td id="T_3936b_row4_col4" class="data row4 col4" >32</td>
#       <td id="T_3936b_row4_col5" class="data row4 col5" >1:16:2</td>
#       <td id="T_3936b_row4_col6" class="data row4 col6" >515016</td>
#       <td id="T_3936b_row4_col7" class="data row4 col7" >0</td>
#       <td id="T_3936b_row4_col8" class="data row4 col8" >1</td>
#       <td id="T_3936b_row4_col9" class="data row4 col9" >(null)</td>
#       <td id="T_3936b_row4_col10" class="data row4 col10" >none</td>
#     </tr>
#     <tr>
#       <th id="T_3936b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3936b_row5_col0" class="data row5 col0" >DT-ZW-21-002</td>
#       <td id="T_3936b_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_3936b_row5_col2" class="data row5 col2" >universe*</td>
#       <td id="T_3936b_row5_col3" class="data row5 col3" >mixed</td>
#       <td id="T_3936b_row5_col4" class="data row5 col4" >20</td>
#       <td id="T_3936b_row5_col5" class="data row5 col5" >1:10:2</td>
#       <td id="T_3936b_row5_col6" class="data row5 col6" >92190</td>
#       <td id="T_3936b_row5_col7" class="data row5 col7" >0</td>
#       <td id="T_3936b_row5_col8" class="data row5 col8" >1</td>
#       <td id="T_3936b_row5_col9" class="data row5 col9" >(null)</td>
#       <td id="T_3936b_row5_col10" class="data row5 col10" >none</td>
#     </tr>
#     <tr>
#       <th id="T_3936b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3936b_row6_col0" class="data row6 col0" >DT-ZW-21-003</td>
#       <td id="T_3936b_row6_col1" class="data row6 col1" >1</td>
#       <td id="T_3936b_row6_col2" class="data row6 col2" >universe*</td>
#       <td id="T_3936b_row6_col3" class="data row6 col3" >mixed</td>
#       <td id="T_3936b_row6_col4" class="data row6 col4" >20</td>
#       <td id="T_3936b_row6_col5" class="data row6 col5" >1:10:2</td>
#       <td id="T_3936b_row6_col6" class="data row6 col6" >92190</td>
#       <td id="T_3936b_row6_col7" class="data row6 col7" >0</td>
#       <td id="T_3936b_row6_col8" class="data row6 col8" >1</td>
#       <td id="T_3936b_row6_col9" class="data row6 col9" >(null)</td>
#       <td id="T_3936b_row6_col10" class="data row6 col10" >none</td>
#     </tr>
#     <tr>
#       <th id="T_3936b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3936b_row7_col0" class="data row7 col0" >DT-ZW-21-005</td>
#       <td id="T_3936b_row7_col1" class="data row7 col1" >1</td>
#       <td id="T_3936b_row7_col2" class="data row7 col2" >universe*</td>
#       <td id="T_3936b_row7_col3" class="data row7 col3" >mixed</td>
#       <td id="T_3936b_row7_col4" class="data row7 col4" >36</td>
#       <td id="T_3936b_row7_col5" class="data row7 col5" >1:18:2</td>
#       <td id="T_3936b_row7_col6" class="data row7 col6" >124384</td>
#       <td id="T_3936b_row7_col7" class="data row7 col7" >0</td>
#       <td id="T_3936b_row7_col8" class="data row7 col8" >1</td>
#       <td id="T_3936b_row7_col9" class="data row7 col9" >(null)</td>

# %% [markdown]
# #### Get squeue

# %%
# squeue
try:
    rc = hpctk.run_remote(["squeue", "-u", user, "-t", "pending,running", "-r"], hpc_mn, ssh_creds, stdout=False)
    hpctk.show_tab_styled_bar(rc.stdout, 0, hpctk.highlight_job_state, ['ST'])

except subprocess.CalledProcessError as e:
    print(f"\n{hpctk.STATE_FAIL} Failed: {e.returncode}\n")
    print(f":: Error message: {e.stderr}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 4
#       2 try:
#       3     rc = hpctk.run_remote(["squeue", "-u", user, "-t", "pending,running", "-r"], hpc_mn, ssh_creds, stdout=False)
# ----> 4     print(f"\n{hpctk.STATE_OK} {rc.stdout}")
#       5     hpctk.show_tab_styled_bar(rc.stdout, 0, hpctk.highlight_job_state, ['ST'])
#       7 except subprocess.CalledProcessError as e:
#
# AttributeError: module 'hpctk' has no attribute 'STATE_OK'

# %% [markdown]
# #### Run job on HPC
